# %%
from nba_api.stats.endpoints import leaguedashplayerstats
import pandas as pd
from nba_api.stats.endpoints import leaguedashteamstats

# %%
player_stats = leaguedashplayerstats.LeagueDashPlayerStats(season='2024-25', season_type_all_star='Regular Season')
team_stats = leaguedashteamstats.LeagueDashTeamStats(season='2024-25', season_type_all_star='Regular Season')

# %%
player_df = player_stats.get_data_frames()[0]
player_df.head()
# Out:
#    PLAYER_ID    PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION   AGE  GP  \
# 0    1630639    A.J. Lawson     A.J.  1610612761               TOR  24.0  26
# 1    1631260       AJ Green       AJ  1610612749               MIL  25.0  73
# 2    1642358     AJ Johnson       AJ  1610612764               WAS  20.0  29
# 3     203932   Aaron Gordon    Aaron  1610612743               DEN  29.0  51
# 4    1628988  Aaron Holiday    Aaron  1610612745               HOU  28.0  62
#
#     W   L  W_PCT  ...  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# 0  14  12  0.538  ...       383        241      200       327       337
# 1  44  29  0.603  ...       370         99      498       290       214
# 2   8  21  0.276  ...       441        312      217       369       347
# 3  33  18  0.647  ...       265        451      301       107       139
# 4  39  23  0.629  ...       311        224      259       292       292
#
#    PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  \
# ...

# %%
player_df.to_csv('/users/nickvoltin/NBA/nba_player_stats_2024_25.csv', index=False)

# %%
team_stats = leaguedashteamstats.LeagueDashTeamStats(season='2024-25', season_type_all_star='Regular Season')
team_df= team_stats.get_data_frames()[0]
team_df
# Out:
#        TEAM_ID               TEAM_NAME  GP   W   L  W_PCT     MIN   FGM   FGA  \
# 0   1610612737           Atlanta Hawks  82  40  42  0.488  3956.0  3556  7528
# 1   1610612738          Boston Celtics  82  61  21  0.744  3966.0  3413  7382
# 2   1610612751           Brooklyn Nets  82  26  56  0.317  3956.0  3086  7060
# 3   1610612766       Charlotte Hornets  82  19  63  0.232  3951.0  3142  7308
# 4   1610612741           Chicago Bulls  82  39  43  0.476  3951.0  3543  7545
# 5   1610612739     Cleveland Cavaliers  82  64  18  0.780  3951.0  3652  7444
# 6   1610612742        Dallas Mavericks  82  39  43  0.476  3946.0  3443  7194
# 7   1610612743          Denver Nuggets  82  50  32  0.610  3971.0  3724  7360
# 8   1610612765         Detroit Pistons  82  44  38  0.537  3961.0  3503  7363
# 9   1610612744   Golden State Warriors  82  48  34  0.585  3946.0  3342  7412
# 10  1610612745         Houston Rockets  82  52  30  0.634  3956.0  3484  7659
# ...

# %%
team_df.to_csv('/users/nickvoltin/NBA/nba_team_stats_2024_25.csv', index=False)

# %%
import csv
import json

# %%
# Read CSV
with open('nba_player_stats_2024_25.csv', mode='r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    data = list(csv_reader)

# %%
# Write JSON
with open('player.json', mode='w') as json_file:
    json.dump(data, json_file, indent=4)

# %%
# Read CSV
with open('nba_team_stats_2024_25.csv', mode='r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    data = list(csv_reader)

# %%
# Write JSON
with open('team.json', mode='w') as json_file:
    json.dump(data, json_file, indent=4)
